# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in ./opt/anaconda3/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.8/site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in ./opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in ./opt/anaconda3/lib/python3.8/site-packages (from folium) (0.4.2)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.8/site-packages (from folium) (1.20.1)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.12.5)

# %%
CLIENT_ID = 'J1M0XTRHBWE15KLRANUDIT2MZL5DALCMWTJFOJ2FVS45NMLY' # your Foursquare ID
CLIENT_SECRET = 'N5JWVWW4NR22RDPP4GWYCU4JLMMRRGXHAFODNPCQDSKQMHKR' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 40
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: J1M0XTRHBWE15KLRANUDIT2MZL5DALCMWTJFOJ2FVS45NMLY
# CLIENT_SECRET:N5JWVWW4NR22RDPP4GWYCU4JLMMRRGXHAFODNPCQDSKQMHKR

# %% [markdown]
# # Data Extraction
#
# In this project we are going to use FourSquare as the datasources to provide the life of shops selling coffee

# %%
import requests

request_parameters = {
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "v": '20180605',
    "section": "coffee",
    "near": "Hong Kong",
    "radius": 1000,
    "limit": 50}

data = requests.get("https://api.foursquare.com/v2/venues/explore", params=request_parameters)
d=data.json()["response"]

# %% [markdown]
# Add the results into Pandas DataFrame for Analysis

# %%
df_raw = []

for item in items:
    venue = item["venue"]
    categories, uid, name, location = venue["categories"], venue["id"], venue["name"], venue["location"]
    
    category = categories[0]["shortName"]
    
    address = location['address']
    lat = location["lat"]
    lng = location["lng"]
    datarow = (uid, name, category, address, lat, lng)
    df_raw.append(datarow)
    
df = pd.DataFrame(df_raw, columns=["uid", "shop", "category", "address", "lat", "lng"])
df.shape[0]
# Out:
# 50

# %%
df
# Out:
#                          uid                              shop  \
# 0   4b1b34f3f964a52093f923e3                     Pret A Manger
# 1   4b42db5af964a52081da25e3                     Fuel Espresso
# 2   53997153498e6ead0c55517b                  Venchi Chocolate
# 3   5a0d44de0531e8240b3b2bea                         % Arabica
# 4   4b0588d9f964a520efdc22e3                     Café Causette
# 5   55012f2c498e77729637acdc                     Coco Espresso
# 6   5a8fdb70f96b2c5099742dcb                     Coco Espresso
# 7   56077b78498e40df12baa041                      Cupping Room
# 8   55866df7498edcdb402ba294               agnès b. café l.p.g
# 9   537c8948498e3e9c9b80a348                         The Envoy
# 10  4efc6e54be7bd3135a6ddae2              agnès b. CAFÉ L.P.G.
# 11  4f275069e5e8940a57d3d658                     Pret A Manger
# 12  546af6e0498ef3a86908ebc8                Sunny Hills (微熱山丘)
# 13  4b8bac69f964a52080a632e3                         Nespresso
# 14  4ee090f50e01452f9264ab4b                           TWG Tea
# 15  594095bb7269fe1c7c7da666                     Fuel Espresso
# 16  51eb71cf498efde267049825                      Cupping Room
# 17  584798f07220e601a0169e32                         Fineprint
# 18  50f8deeee4b0c24382136fa2                     Common Ground
# 19  563b2b85cd102e39b962a2f4                            Why 50
# 20  5b18ecaff62f2b0039b6164c                 Barista By Givres
# 21  4cc8d11fdbc376b00bdba3bc  Sweet Secrets Cafe and Cake Shop
# 22  4d47b54d11618cfa3d2fcc23                     Fuel Espresso
# 23  58f7177dec79e20cae15ce77             Halfway Coffee (半路咖啡)
# 24  50de6806e4b0fe5bc341bc72                   Hazel & Hershey
# 25  585f7dd007ac07684412779f                     Sweetpea Café
# 26  4f1314ae1081cbea0521eb7f                        mymy Caffè
# 27  50ea402c80550ef207081472                        Café Queen
# 28  4b5b248af964a5202fe628e3                    Veggie SF Café
# 29  4f06c1f0e4b0e53f582b66be                      Teakha (茶·家)
# 30  56ab5c04498e9e5b39df6362                             Metta
# 31  50910215e4b07b9c2dba6264  Le Salon de Thé de Joël Robuchon
# 32  58cb7ecd2bc5e20a90d019ba                  Elephant Grounds
# 33  4b30d8c0f964a52017fc24e3                        Classified
# 34  585df84b8d8e995f7383927f                      Cupping Room
# 35  551753e2498eb43066c33d41                           TheNest
# 36  584ccb478f0be42a4d8b96ed              The Coffee Academics
# 37  5743ccc6498ec71de6b986d3                              NODI
# 38  4ba3a212f964a520244e38e3                   Starbucks (星巴克)
# 39  56272616498e4e24f054aef7              Lady M Cake Boutique
# 40  592ff27dc3658844b47d532d                         Tom Dixon
# 41  4b7f78faf964a520803030e3                       Barista Jam
# 42  4caab8c436fa6dcb00f8d278                       The Canteen
# 43  52f1f07b498e3a724184aa03                      Filters Lane
# 44  519c6e2a498e5fbb88cd86df                  Freshness Coffee
# 45  52a147b0498e069268ea7411                            Café 8
# 46  5125af34e4b0cb7220ffca32                           Caféine
# 47  4eacd882775bad292f30b122                   simplylife CAFÉ
# 48  4cfb7023c671721e5b8dc318                             Homei
# 49  529b3100498ef27b34483538                       Man Mo Café
#
#               category                                            address  \
# 0           Sandwiches        Unit 1015, 1/F, ifc mall, 1 Harbour View St
# 1          Coffee Shop        Shop 3023, 3/F, IFC Mall, 1 Harbour View St
# 2             Desserts                                     Stanley Street
# 3          Coffee Shop                            G/F Shop 1050, ifc mall
# 4                 Café  M/F, Mandarin Oriental Hong Kong, 5 Connaught ...
# 5                 Café      Shop D, G/F, World Trust Tower, 50 Stanley St
# 6          Coffee Shop                               13-15 Jervois Street
# 7          Coffee Shop                                     18 Cochrane St
# 8                 Café  Shop 3002-05 podium Level 3, IFC Mall, 1Harbou...
# 9             Cocktail      3/F, The Pottinger Hong Kong, 74 Queen's Rd C
# 10                Café                G/F, Chung San House, 8-10 Gough St
# 11          Sandwiches  Shop 1, Entrance Hall, The Center, 99 Queen's ...
# 12              Bakery                                 G/F, 8 Chancery Ln
# 13         Coffee Shop        Shop 1058, 1/F, IFC Mall, 1 Harbour View St
# 14            Tea Room   Shop 1022-1023, 1/F, IFC Mall, 1 Harbour View St
# 15         Coffee Shop                    G/F, Chater House, 25 Chater Rd
